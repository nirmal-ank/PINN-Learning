# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmal-ank/PINN-Learning/blob/main/nvidia_modulus_ns_LDC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install NVIDIA Modulus

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install virtualenv
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.26.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (3.15.4)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (4.2.2)
# Downloading virtualenv-20.26.3-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 62.9 MB/s eta 0:00:00
# Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 36.4 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.3.8 virtualenv-20.26.3

# %%
# !virtualenv /content/drive/MyDrive/virtual_env
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 16006ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/virtual_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==24.1, setuptools==70.1.0, wheel==0.43.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
 # !source /content/drive/MyDrive/virtual_env/bin/activate; pip install nvidia-modulus nvidia-modulus-sym
# Out:
# Collecting nvidia-modulus
#   Downloading nvidia_modulus-0.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting nvidia-modulus-sym
#   Downloading nvidia_modulus.sym-1.6.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting torch>=2.0.0 (from nvidia-modulus)
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting numpy<1.25,>=1.22.4 (from nvidia-modulus)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting xarray>=2023.1.0 (from nvidia-modulus)
#   Downloading xarray-2024.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting zarr>=2.14.2 (from nvidia-modulus)
#   Downloading zarr-2.18.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting fsspec>=2023.1.0 (from nvidia-modulus)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting s3fs>=2023.5.0 (from nvidia-modulus)
#   Downloading s3fs-2024.6.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting nvidia-dali-cuda120>=1.35.0 (from nvidia-modulus)
#   Downloading nvidia_dali_cuda120-1.40.0.tar.gz (1.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=67.6.0 in ./drive/MyDrive/virtual_env/lib/python3.10/site-packages (from nvidia-modulus) (70.1.0)
# Collecting certifi>=2023.7.22 (from nvidia-modulus)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting pytz>=2023.3 (from nvidia-modulus)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting treelib>=1.2.5 (from nvidia-modulus)
#   Downloading treelib-1.7.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting tqdm>=4.60.0 (from nvidia-modulus)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting nvtx>=0.2.8 (from nvidia-modulus)
#   Using cached nvtx-0.2.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (740 bytes)
# Collecting onnx>=1.14.0 (from nvidia-modulus)
#   Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting timm>=0.9.12 (from nvidia-modulus)
#   Downloading timm-1.0.8-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.9 MB/s eta 0:00:00
# Collecting hydra-core>=1.2.0 (from nvidia-modulus-sym)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting termcolor>=2.1.1 (from nvidia-modulus-sym)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting chaospy>=4.3.7 (from nvidia-modulus-sym)
#   Downloading chaospy-4.3.16-py3-none-any.whl.metadata (5.4 kB)
# Collecting Cython==0.29.28 (from nvidia-modulus-sym)
#   Downloading Cython-0.29.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (2.8 kB)
# Collecting numpy-stl==2.16.3 (from nvidia-modulus-sym)
#   Downloading numpy-stl-2.16.3.tar.gz (772 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.1/772.1 kB 26.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting opencv-python==4.9.0.80 (from nvidia-modulus-sym)
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting scikit-learn>=1.2.0 (from nvidia-modulus-sym)
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting symengine>=0.10.0 (from nvidia-modulus-sym)
#   Downloading symengine-0.11.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (1.2 kB)
# Collecting sympy==1.12 (from nvidia-modulus-sym)
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting torch-optimizer==0.3.0 (from nvidia-modulus-sym)
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 5.2 MB/s eta 0:00:00
# Collecting transforms3d==0.3.1 (from nvidia-modulus-sym)
#   Downloading transforms3d-0.3.1.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting typing==3.7.4.3 (from nvidia-modulus-sym)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pillow==10.2.0 (from nvidia-modulus-sym)
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting notebook==6.4.12 (from nvidia-modulus-sym)
#   Downloading notebook-6.4.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting mistune==2.0.3 (from nvidia-modulus-sym)
#   Downloading mistune-2.0.3-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting pint==0.19.2 (from nvidia-modulus-sym)
#   Downloading Pint-0.19.2.tar.gz (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.0/292.0 kB 28.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tensorboard>=2.8.0 (from nvidia-modulus-sym)
#   Using cached tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting vtk>=9.2.6 (from nvidia-modulus-sym)
#   Downloading vtk-9.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting h5py>=3.7.0 (from nvidia-modulus-sym)
#   Using cached h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting jinja2 (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting tornado>=6.1 (from notebook==6.4.12->nvidia-modulus-sym)
#   Downloading tornado-6.4.1-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting pyzmq>=17 (from notebook==6.4.12->nvidia-modulus-sym)
#   Downloading pyzmq-26.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting argon2-cffi (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting traitlets>=4.2.1 (from notebook==6.4.12->nvidia-modulus-sym)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-core>=4.6.1 (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting jupyter-client>=5.3.4 (from notebook==6.4.12->nvidia-modulus-sym)
#   Downloading jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting ipython-genutils (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting nbformat (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting nbconvert>=5 (from notebook==6.4.12->nvidia-modulus-sym)
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting nest-asyncio>=1.5 (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting ipykernel (from notebook==6.4.12->nvidia-modulus-sym)
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting Send2Trash>=1.8.0 (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client (from notebook==6.4.12->nvidia-modulus-sym)
#   Using cached prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting python-utils>=1.6.2 (from numpy-stl==2.16.3->nvidia-modulus-sym)
#   Using cached python_utils-3.8.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting mpmath>=0.19 (from sympy==1.12->nvidia-modulus-sym)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pytorch-ranger>=0.1.1 (from torch-optimizer==0.3.0->nvidia-modulus-sym)
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl.metadata (509 bytes)
# Collecting numpoly>=1.2.12 (from chaospy>=4.3.7->nvidia-modulus-sym)
#   Downloading numpoly-1.2.13-py3-none-any.whl.metadata (6.0 kB)
# Collecting scipy (from chaospy>=4.3.7->nvidia-modulus-sym)
#   Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.3 MB/s eta 0:00:00
# Collecting importlib-metadata (from chaospy>=4.3.7->nvidia-modulus-sym)
#   Using cached importlib_metadata-8.2.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.2.0->nvidia-modulus-sym)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.2.0->nvidia-modulus-sym)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting packaging (from hydra-core>=1.2.0->nvidia-modulus-sym)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting astunparse>=1.6.0 (from nvidia-dali-cuda120>=1.35.0->nvidia-modulus)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting gast>=0.3.3 (from nvidia-dali-cuda120>=1.35.0->nvidia-modulus)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting dm-tree (from nvidia-dali-cuda120>=1.35.0->nvidia-modulus)
#   Using cached dm_tree-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-nvimgcodec-cu12>=0.2.0 (from nvidia-dali-cuda120>=1.35.0->nvidia-modulus)
#   Downloading nvidia_nvimgcodec_cu12-0.3.0.5-py3-none-manylinux2014_x86_64.whl.metadata (761 bytes)
# Collecting protobuf>=3.20.2 (from onnx>=1.14.0->nvidia-modulus)
#   Downloading protobuf-5.27.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2023.5.0->nvidia-modulus)
#   Downloading aiobotocore-2.13.2-py3-none-any.whl.metadata (22 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs>=2023.5.0->nvidia-modulus)
#   Downloading aiohttp-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.2.0->nvidia-modulus-sym)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.2.0->nvidia-modulus-sym)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.8.0->nvidia-modulus-sym)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.8.0->nvidia-modulus-sym)
#   Downloading grpcio-1.65.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.8.0->nvidia-modulus-sym)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf>=3.20.2 (from onnx>=1.14.0->nvidia-modulus)
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting six>1.9 (from tensorboard>=2.8.0->nvidia-modulus-sym)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.8.0->nvidia-modulus-sym)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.8.0->nvidia-modulus-sym)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting torchvision (from timm>=0.9.12->nvidia-modulus)
#   Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting pyyaml (from timm>=0.9.12->nvidia-modulus)
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface_hub (from timm>=0.9.12->nvidia-modulus)
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors (from timm>=0.9.12->nvidia-modulus)
#   Using cached safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting filelock (from torch>=2.0.0->nvidia-modulus)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch>=2.0.0->nvidia-modulus)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch>=2.0.0->nvidia-modulus)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->nvidia-modulus)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.0.0->nvidia-modulus)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->nvidia-modulus)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting matplotlib>=2.0.0 (from vtk>=9.2.6->nvidia-modulus-sym)
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pandas>=2.0 (from xarray>=2023.1.0->nvidia-modulus)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting asciitree (from zarr>=2.14.2->nvidia-modulus)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numcodecs>=0.10.0 (from zarr>=2.14.2->nvidia-modulus)
#   Downloading numcodecs-0.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Collecting fasteners (from zarr>=2.14.2->nvidia-modulus)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting botocore<1.34.132,>=1.34.70 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.5.0->nvidia-modulus)
#   Downloading botocore-1.34.131-py3-none-any.whl.metadata (5.7 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.5.0->nvidia-modulus)
#   Downloading aioitertools-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Downloading aiohappyeyeballs-2.3.5-py3-none-any.whl.metadata (5.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./drive/MyDrive/virtual_env/lib/python3.10/site-packages (from astunparse>=1.6.0->nvidia-dali-cuda120>=1.35.0->nvidia-modulus) (0.43.0)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=5.3.4->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core>=4.6.1->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached platformdirs-4.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.0.0->vtk>=9.2.6->nvidia-modulus-sym)
#   Using cached contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->vtk>=9.2.6->nvidia-modulus-sym)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.0.0->vtk>=9.2.6->nvidia-modulus-sym)
#   Using cached fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.0.0->vtk>=9.2.6->nvidia-modulus-sym)
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.0.0->vtk>=9.2.6->nvidia-modulus-sym)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting beautifulsoup4 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markupsafe>=2.0 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting pygments>=2.4.1 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting tinycss2 (from nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=2.6 (from nbformat->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.0->xarray>=2023.1.0->nvidia-modulus)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting ptyprocess (from terminado>=0.8.3->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting requests (from huggingface_hub->timm>=0.9.12->nvidia-modulus)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting zipp>=0.5 (from importlib-metadata->chaospy>=4.3.7->nvidia-modulus-sym)
#   Downloading zipp-3.20.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting comm>=0.1.1 (from ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading debugpy-1.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting ipython>=7.23.1 (from ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading ipython-8.26.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting psutil (from ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.5.0->nvidia-modulus)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.5.0->nvidia-modulus)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached prompt_toolkit-3.0.47-py3-none-any.whl.metadata (6.4 kB)
# Collecting stack-data (from ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting exceptiongroup (from ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached rpds_py-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting idna>=2.0 (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.5.0->nvidia-modulus)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached cffi-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=5->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface_hub->timm>=0.9.12->nvidia-modulus)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.4.12->nvidia-modulus-sym)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading nvidia_modulus-0.7.0-py3-none-any.whl (448 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.1/448.1 kB 36.3 MB/s eta 0:00:00
# Downloading nvidia_modulus.sym-1.6.0-py3-none-any.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.6/291.6 kB 28.1 MB/s eta 0:00:00
# Downloading Cython-0.29.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 69.7 MB/s eta 0:00:00
# Downloading mistune-2.0.3-py2.py3-none-any.whl (24 kB)
# Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 77.9 MB/s eta 0:00:00
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 10.1 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 71.1 MB/s eta 0:00:00
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 76.0 MB/s eta 0:00:00
# Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 5.3 MB/s eta 0:00:00
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Downloading chaospy-4.3.16-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 19.1 MB/s eta 0:00:00
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.7 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 71.5 MB/s eta 0:00:00
# Using cached nvtx-0.2.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
# Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 91.3 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading s3fs-2024.6.1-py3-none-any.whl (29 kB)
# Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 97.4 MB/s eta 0:00:00
# Downloading symengine-0.11.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (39.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 13.1 MB/s eta 0:00:00
# Using cached tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading timm-1.0.8-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 88.1 MB/s eta 0:00:00
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.4 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.9 MB/s eta 0:00:00
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading treelib-1.7.0-py3-none-any.whl (18 kB)
# Downloading vtk-9.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 MB 8.8 MB/s eta 0:00:00
# Downloading xarray-2024.7.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.1 MB/s eta 0:00:00
# Downloading zarr-2.18.2-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.2/210.2 kB 20.0 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 14.1 MB/s eta 0:00:00
# Downloading aiobotocore-2.13.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 6.4 MB/s eta 0:00:00
# Downloading aiohttp-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.3 MB/s eta 0:00:00
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading grpcio-1.65.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 109.1 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading jupyter_client-8.6.2-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 11.0 MB/s eta 0:00:00
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 107.8 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 24.5 MB/s eta 0:00:00
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading numcodecs-0.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 109.1 MB/s eta 0:00:00
# Downloading numpoly-1.2.13-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 13.5 MB/s eta 0:00:00
# Downloading nvidia_nvimgcodec_cu12-0.3.0.5-py3-none-manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 120.5 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.7 MB/s eta 0:00:00
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 108.9 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 27.7 MB/s eta 0:00:00
# Using cached python_utils-3.8.2-py2.py3-none-any.whl (27 kB)
# Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Downloading pyzmq-26.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (868 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.6/868.6 kB 53.0 MB/s eta 0:00:00
# Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 15.8 MB/s eta 0:00:00
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tornado-6.4.1-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.8/436.8 kB 35.7 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.7 MB/s eta 0:00:00
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached dm_tree-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 28.9 MB/s eta 0:00:00
# Using cached importlib_metadata-8.2.0-py3-none-any.whl (25 kB)
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 11.2 MB/s eta 0:00:00
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Using cached safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 106.7 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.3.5-py3-none-any.whl (12 kB)
# Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Downloading botocore-1.34.131-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 113.4 MB/s eta 0:00:00
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading debugpy-1.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 95.1 MB/s eta 0:00:00
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
# Downloading ipython-8.26.0-py3-none-any.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.9/817.9 kB 51.2 MB/s eta 0:00:00
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Using cached platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 64.0 MB/s eta 0:00:00
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 22.9 MB/s eta 0:00:00
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Using cached yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Downloading zipp-3.20.0-py3-none-any.whl (9.4 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 24.6 MB/s eta 0:00:00
# Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Using cached cffi-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Using cached prompt_toolkit-3.0.47-py3-none-any.whl (386 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 10.8 MB/s eta 0:00:00
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: numpy-stl, pint, transforms3d, typing, antlr4-python3-runtime, nvidia-dali-cuda120, asciitree
#   Building wheel for numpy-stl (setup.py) ... done
#   Created wheel for numpy-stl: filename=numpy_stl-2.16.3-py3-none-any.whl size=18655 sha256=d17106cdc57e3fb3515ffb7d0e114403c36f192edbc4f28cb9ad5b9bd669c555
#   Stored in directory: /root/.cache/pip/wheels/51/59/9f/28b045800f3ca6beca8d9805d68009f1b006bb7ad67bb3b892
#   Building wheel for pint (pyproject.toml) ... done
#   Created wheel for pint: filename=Pint-0.19.2-py3-none-any.whl size=231002 sha256=e8d4d21f14552dea5e380a78378b14be099dfbafbb22eeb99691ecf2e03c8249
#   Stored in directory: /root/.cache/pip/wheels/eb/00/87/c216aa83b91597845d9fec6fcd9dbe31c945a25d968dd4765a
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-py3-none-any.whl size=59357 sha256=b624910a5c2ec2a2c4580c228b9a7a4d082bc7fe213db664f3e2b16df6b6d31b
#   Stored in directory: /root/.cache/pip/wheels/2f/b6/70/b90dfb92fc3eab4cd4fe00a49f5f45cbcd203678ab6379e9d4
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26305 sha256=05c347f0d8a5cd42d5af9ad5992bff60f9f91ae4453c7d37bffcf401eea0bedb
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144553 sha256=4bca8ae31711162a409112f2c35e6e414a1b89d357a1a1dbe37d2db33b2b28f3
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for nvidia-dali-cuda120 (pyproject.toml) ... done
#   Created wheel for nvidia-dali-cuda120: filename=nvidia_dali_cuda120-1.40.0-16741769-py3-none-manylinux2014_x86_64.whl size=301699769 sha256=b641d0e6e2b4a48c31232c10ab63b64b5b098b0538c48c1a35076950f08ca9b9
#   Stored in directory: /root/.cache/pip/wheels/08/83/b2/89a6d5d1cbfbedf71cd165bf311ee8385fece19513fe0976d5
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5033 sha256=65d34adcc0dbd9028d213d4ebb97d24c479683bd94d2611b9838ada288ab748e
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built numpy-stl pint transforms3d typing antlr4-python3-runtime nvidia-dali-cuda120 asciitree
# Installing collected packages: webencodings, wcwidth, transforms3d, pytz, pure-eval, ptyprocess, nvtx, mpmath, mistune, ipython-genutils, fastjsonschema, dm-tree, asciitree, antlr4-python3-runtime, zipp, wrapt, urllib3, tzdata, typing-extensions, typing, traitlets, tqdm, tornado, tinycss2, threadpoolctl, termcolor, tensorboard-data-server, sympy, symengine, soupsieve, six, Send2Trash, safetensors, rpds-py, pyzmq, pyyaml, pyparsing, pygments, pycparser, psutil, protobuf, prompt-toolkit, prometheus-client, platformdirs, pint, pillow, pexpect, parso, pandocfilters, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nvimgcodec-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, nest-asyncio, multidict, markupsafe, markdown, kiwisolver, jupyterlab-pygments, joblib, jmespath, idna, grpcio, gast, fsspec, frozenlist, fonttools, filelock, fasteners, executing, exceptiongroup, defusedxml, decorator, debugpy, Cython, cycler, charset-normalizer, certifi, attrs, async-timeout, aioitertools, aiohappyeyeballs, absl-py, yarl, werkzeug, triton, treelib, terminado, scipy, requests, referencing, python-utils, python-dateutil, opencv-python, onnx, omegaconf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numcodecs, matplotlib-inline, jupyter-core, jinja2, jedi, importlib-metadata, h5py, contourpy, comm, cffi, bleach, beautifulsoup4, astunparse, asttokens, aiosignal, zarr, tensorboard, stack-data, scikit-learn, pandas, nvidia-dali-cuda120, nvidia-cusolver-cu12, numpy-stl, numpoly, matplotlib, jupyter-client, jsonschema-specifications, hydra-core, huggingface_hub, botocore, argon2-cffi-bindings, aiohttp, xarray, vtk, torch, jsonschema, ipython, chaospy, argon2-cffi, aiobotocore, torchvision, s3fs, pytorch-ranger, nbformat, ipykernel, torch-optimizer, timm, nbclient, nvidia-modulus, nbconvert, notebook, nvidia-modulus-sym
# Successfully installed Cython-0.29.28 Send2Trash-1.8.3 absl-py-2.1.0 aiobotocore-2.13.2 aiohappyeyeballs-2.3.5 aiohttp-3.10.3 aioitertools-0.11.0 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 asciitree-0.3.3 asttokens-2.4.1 astunparse-1.6.3 async-timeout-4.0.3 attrs-24.2.0 beautifulsoup4-4.12.3 bleach-6.1.0 botocore-1.34.131 certifi-2024.7.4 cffi-1.17.0 chaospy-4.3.16 charset-normalizer-3.3.2 comm-0.2.2 contourpy-1.2.1 cycler-0.12.1 debugpy-1.8.5 decorator-5.1.1 defusedxml-0.7.1 dm-tree-0.1.8 exceptiongroup-1.2.2 executing-2.0.1 fasteners-0.19 fastjsonschema-2.20.0 filelock-3.15.4 fonttools-4.53.1 frozenlist-1.4.1 fsspec-2024.6.1 gast-0.6.0 grpcio-1.65.4 h5py-3.11.0 huggingface_hub-0.24.5 hydra-core-1.3.2 idna-3.7 importlib-metadata-8.2.0 ipykernel-6.29.5 ipython-8.26.0 ipython-genutils-0.2.0 jedi-0.19.1 jinja2-3.1.4 jmespath-1.0.1 joblib-1.4.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-client-8.6.2 jupyter-core-5.7.2 jupyterlab-pygments-0.3.0 kiwisolver-1.4.5 markdown-3.6 markupsafe-2.1.5 matplotlib-3.9.2 matplotlib-inline-0.1.7 mistune-2.0.3 mpmath-1.3.0 multidict-6.0.5 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 nest-asyncio-1.6.0 networkx-3.3 notebook-6.4.12 numcodecs-0.13.0 numpoly-1.2.13 numpy-1.24.4 numpy-stl-2.16.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-dali-cuda120-1.40.0 nvidia-modulus-0.7.0 nvidia-modulus-sym-1.6.0 nvidia-nccl-cu12-2.20.5 nvidia-nvimgcodec-cu12-0.3.0.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 nvtx-0.2.10 omegaconf-2.3.0 onnx-1.16.2 opencv-python-4.9.0.80 packaging-24.1 pandas-2.2.2 pandocfilters-1.5.1 parso-0.8.4 pexpect-4.9.0 pillow-10.2.0 pint-0.19.2 platformdirs-4.2.2 prometheus-client-0.20.0 prompt-toolkit-3.0.47 protobuf-4.25.4 psutil-6.0.0 ptyprocess-0.7.0 pure-eval-0.2.3 pycparser-2.22 pygments-2.18.0 pyparsing-3.1.2 python-dateutil-2.9.0.post0 python-utils-3.8.2 pytorch-ranger-0.1.1 pytz-2024.1 pyyaml-6.0.2 pyzmq-26.1.0 referencing-0.35.1 requests-2.32.3 rpds-py-0.20.0 s3fs-2024.6.1 safetensors-0.4.4 scikit-learn-1.5.1 scipy-1.14.0 six-1.16.0 soupsieve-2.6 stack-data-0.6.3 symengine-0.11.0 sympy-1.12 tensorboard-2.17.0 tensorboard-data-server-0.7.2 termcolor-2.4.0 terminado-0.18.1 threadpoolctl-3.5.0 timm-1.0.8 tinycss2-1.3.0 torch-2.4.0 torch-optimizer-0.3.0 torchvision-0.19.0 tornado-6.4.1 tqdm-4.66.5 traitlets-5.14.3 transforms3d-0.3.1 treelib-1.7.0 triton-3.0.0 typing-3.7.4.3 typing-extensions-4.12.2 tzdata-2024.1 urllib3-2.2.2 vtk-9.3.1 wcwidth-0.2.13 webencodings-0.5.1 werkzeug-3.0.3 wrapt-1.16.0 xarray-2024.7.0 yarl-1.9.4 zarr-2.18.2 zipp-3.20.0

# %%
import sys
# add the path of the virtual environmentsite-packages to colab system path
sys.path.append("/content/drive/MyDrive/virtual_env/lib/python3.10/site-packages")

# %% [markdown]
# # Import Required Libraries

# %%
import os
import warnings
import torch
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, Eq, Abs

# %% [markdown]
# For educational purposes, we will actually import the NVIDIA Modulus modules in parts as we need them.
#
# But you can import them from the beginning like this.

# %%
import modulus.sym
from modulus.sym.hydra import to_absolute_path, instantiate_arch, ModulusConfig
from modulus.sym.solver import Solver
from modulus.sym.domain import Domain
from modulus.sym.geometry.primitives_2d import Rectangle
from modulus.sym.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseInteriorConstraint,
    PointwiseConstraint
)
from modulus.sym.domain.validator import PointwiseValidator
from modulus.sym.domain.inferencer import PointwiseInferencer
from modulus.sym.key import Key
from modulus.sym.eq.pdes.navier_stokes import NavierStokes
from modulus.sym.utils.io import (
    csv_to_dict,
    ValidatorPlotter,
    InferencerPlotter
)

# %% [markdown]
# # Navier Stokes PDEs

# %% [markdown]
# I recommend you check out the GitHub repository of NVIDIA modulus where this equation is defined:
#
# https://github.com/NVIDIA/modulus-sym/blob/main/modulus/sym/eq/pdes/navier_stokes.py

# %%
from modulus.sym.eq.pdes.navier_stokes import NavierStokes

# %%
ns = NavierStokes(nu=0.01, rho=1.0, dim=2, time=False)

# %%
ns.equations
# Out:
# {'continuity': 1.0*Derivative(u(x, y), x) + 1.0*Derivative(v(x, y), y),
#  'momentum_x': 1.0*u(x, y)*Derivative(u(x, y), x) + 1.0*v(x, y)*Derivative(u(x, y), y) + Derivative(p(x, y), x) - 0.01*Derivative(u(x, y), (x, 2)) - 0.01*Derivative(u(x, y), (y, 2)),
#  'momentum_y': 1.0*u(x, y)*Derivative(v(x, y), x) + 1.0*v(x, y)*Derivative(v(x, y), y) + Derivative(p(x, y), y) - 0.01*Derivative(v(x, y), (x, 2)) - 0.01*Derivative(v(x, y), (y, 2))}

# %%
ns.pprint()
# Out:
# continuity: 1.0*u__x + 1.0*v__y
# momentum_x: 1.0*u*u__x + 1.0*v*u__y + p__x - 0.01*u__x__x - 0.01*u__y__y
# momentum_y: 1.0*u*v__x + 1.0*v*v__y + p__y - 0.01*v__x__x - 0.01*v__y__y

# %%
ns.equations['continuity']
# Out:
#     ∂                 ∂
# 1.0⋅──(u(x, y)) + 1.0⋅──(v(x, y))
#     ∂x                ∂y

# %%
ns.equations['momentum_x']
# Out:
#                                                                         2                   2      ↪
#             ∂                         ∂             ∂                  ∂                   ∂       ↪
# 1.0⋅u(x, y)⋅──(u(x, y)) + 1.0⋅v(x, y)⋅──(u(x, y)) + ──(p(x, y)) - 0.01⋅───(u(x, y)) - 0.01⋅───(u(x ↪
#             ∂x                        ∂y            ∂x                   2                   2     ↪
#                                                                        ∂x                  ∂y      ↪
#
# ↪
# ↪
# ↪ , y))
# ↪
# ↪

# %%
ns.equations['momentum_y']
# Out:
#                                                                         2                   2      ↪
#             ∂                         ∂             ∂                  ∂                   ∂       ↪
# 1.0⋅u(x, y)⋅──(v(x, y)) + 1.0⋅v(x, y)⋅──(v(x, y)) + ──(p(x, y)) - 0.01⋅───(v(x, y)) - 0.01⋅───(v(x ↪
#             ∂x                        ∂y            ∂y                   2                   2     ↪
#                                                                        ∂x                  ∂y      ↪
#
# ↪
# ↪
# ↪ , y))
# ↪
# ↪

# %% [markdown]
# # Neural Network

# %% [markdown]
# The docs recommend defining the neural network architecture with a configuration file:
#
# https://docs.nvidia.com/deeplearning/modulus/modulus-sym/user_guide/basics/lid_driven_cavity_flow.html#creating-a-neural-network-node
#
# But we'll do it with code ;)

# %% [markdown]
# This is because we want to understand what actually happens behind the scenes a little better, and that is why I also recommend you check out the `arch.py` file in the NVIDIA Modulus repository where the data classes are defined:
#
# https://github.com/NVIDIA/modulus-sym/blob/f59eba4d852a65cc80f703da754a87e51ba44d9d/modulus/sym/hydra/arch.py#L94

# %%
'''
modulus/sym/hydra/arch.py
@dataclass
class FullyConnectedConf(ModelConf):

    arch_type: str = "fully_connected"
    layer_size: int = 512
    nr_layers: int = 6
    skip_connections: bool = False
    activation_fn: str = "silu"
    adaptive_activations: bool = False
    weight_norm: bool = True
'''

# flow_net = instantiate_arch(
#     input_keys=[Key("x"), Key("y")],
#     output_keys=[Key("u"), Key("v"), Key("p")],
#     cfg=cfg.arch.fully_connected
# )

# https://docs.nvidia.com/deeplearning/modulus/modulus-sym/user_guide/features/configuration.html#config
from modulus.sym.models.fully_connected import FullyConnectedArch
from modulus.sym.models.activation import Activation
from modulus.sym.key import Key

flow_net = FullyConnectedArch(
    input_keys=[Key("x"), Key("y")],
    output_keys=[Key("u"), Key("v"), Key("p")],
    layer_size=512,
    nr_layers=6,
    skip_connections=False,
    activation_fn=Activation.SILU,
    adaptive_activations=False,
    weight_norm=True,
)

# %%
flow_net
# Out:
# FullyConnectedArch(
#   (_impl): FullyConnectedArchCore(
#     (layers): ModuleList(
#       (0): FCLayer(
#         (linear): WeightNormLinear(in_features=2, out_features=512, bias=True)
#       )
#       (1-5): 5 x FCLayer(
#         (linear): WeightNormLinear(in_features=512, out_features=512, bias=True)
#       )
#     )
#     (final_layer): FCLayer(
#       (activation_fn): Identity()
#       (linear): Linear(in_features=512, out_features=3, bias=True)
#     )
#   )
# )

# %%
nodes = ns.make_nodes() + [flow_net.make_node(name="flow_network")]

# %%
nodes
# Out:
# [<modulus.sym.node.Node at 0x7fa91e7cb2b0>,
#  <modulus.sym.node.Node at 0x7fa91e7c9fc0>,
#  <modulus.sym.node.Node at 0x7fa9d112d9f0>,
#  <modulus.sym.node.Node at 0x7fa91e7cb790>]

# %% [markdown]
# # Geometry

# %%
height = 0.1
width = 0.1
x, y = Symbol("x"), Symbol("y")
rec = Rectangle((-width / 2, -height / 2), (width / 2, height / 2))

# %%
rec

# %% [markdown]
# # Constraints

# %% [markdown]
# ## Domain

# %%
ldc_domain = Domain()

# %% [markdown]
# ## Boundary Constraints

# %%
# top wall
top_wall = PointwiseBoundaryConstraint(
    nodes=nodes,
    geometry=rec,
    outvar={"u": 1.0, "v": 0},
    # batch_size=cfg.batch_size.TopWall
    batch_size=1000,
    # weight edges to be zero at the corners (x goes from -0.05 to -.05)
    lambda_weighting={"u":
                      1.0 - 20 * Abs(x)
                      # Symbol("sdf") # doesn't work
                      , "v": 1.0},
    criteria=Eq(y, height / 2) # would this work as y == height / 2
)

ldc_domain.add_constraint(top_wall, "top_wall")


# no slip
no_slip = PointwiseBoundaryConstraint(
    nodes=nodes,
    geometry=rec,
    outvar={"u": 0, "v": 0},
    batch_size=1000,
    criteria=y < height / 2
)

ldc_domain.add_constraint(no_slip, "no_slip")

# %% [markdown]
# ## Interior Constraints

# %%
# interior
interior = PointwiseInteriorConstraint(
    nodes=nodes,
    geometry=rec,
    outvar={"continuity": 0, "momentum_x": 0, "momentum_y": 0},
    batch_size=4000,
    lambda_weighting={
# https://docs.nvidia.com/deeplearning/modulus/modulus-sym/user_guide/theory/recommended_practices.html#spatial-loss-weighting
# Signed Distance Function (SDF)
#
# "...this sharp discontinuity can be avoided by specifying the weighting for
# this boundary such that the weight of the loss varies continuously and is 0
# on the boundaries."
#
        "continuity": Symbol("sdf"),
        "momentum_x": Symbol("sdf"),
        "momentum_y": Symbol("sdf"),
    },
)

ldc_domain.add_constraint(interior, "interior")

# %% [markdown]
# https://docs.nvidia.com/deeplearning/modulus/modulus-sym/user_guide/basics/lid_driven_cavity_flow.html#creating-a-neural-network-node

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solver Configuration

# %% [markdown]
# The user guide shows how to convert a configuration file into a configuration object.
#
# https://docs.nvidia.com/deeplearning/modulus/modulus-sym-v110/notebook.nbconvert.html

# %%
# %%writefile config.yaml
#
# defaults:
#   - modulus_default
#   - arch: fully_connected
#   - scheduler: tf_exponential_lr
#   - optimizer: adam
#   - loss: sum
#   - _self_
#
# scheduler:
#   decay_rate: 0.95
#   decay_steps: 4000
#
# training:
#   rec_validation_freq: 1000
#   rec_inference_freq: 2000
#   rec_monitor_freq: 1000
#   rec_constraint_freq: 2000
#   max_steps: 10000
#
# batch_size:
#   TopWall: 1000
#   NoSlip: 1000
#   Interior: 4000
#
# graph:
#   func_arch: true
# Out:
# Writing config.yaml

# %%
import modulus.sym
from modulus.sym.hydra import to_yaml
from modulus.sym.hydra.utils import compose
from modulus.sym.hydra.config import ModulusConfig

cfg = compose(config_path=".", config_name="config")
cfg.network_dir = 'outputs' # Set the network directory for checkpoints
print(to_yaml(cfg))
# Out:
# /content/drive/MyDrive/virtual_env/lib/python3.10/site-packages/modulus/sym/hydra/utils.py:150: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(
# WARNING:modulus.sym.hydra.config:TorchScript default is being turned off due to PyTorch version mismatch.
# training:
#   max_steps: 10000
#   grad_agg_freq: 1
#   rec_results_freq: 1000
#   rec_validation_freq: 1000
#   rec_inference_freq: 2000
#   rec_monitor_freq: 1000
#   rec_constraint_freq: 2000
#   save_network_freq: 1000
#   print_stats_freq: 100
#   summary_freq: 1000
#   amp: false
#   amp_dtype: float16
#   ntk:
#     use_ntk: false
#     save_name: null
#     run_freq: 1000
# graph:
#   func_arch: true
#   func_arch_allow_partial_hessian: true
# stop_criterion:
#   metric: null
#   min_delta: null
#   patience: 50000
#   mode: min
#   freq: 1000
#   strict: false
# profiler:
#   profile: false
#   start_step: 0
#   end_step: 100
#   name: nvtx
# network_dir: outputs
# initialization_network_dir: ''
# save_filetypes: vtk
# summary_histograms: false
# jit: true
# jit_use_nvfuser: true
# jit_arch_mode: only_activation
# jit_autograd_nodes: false
# cuda_graphs: true
# cuda_graph_warmup: 20
# find_unused_parameters: false
# broadcast_buffers: false
# device: ''
# debug: false
# run_mode: train
# arch:
#   fully_connected:
#     arch_type: fully_connected
#     input_keys: ???
#     output_keys: ???
#     detach_keys: ???
#     scaling: null
#     layer_size: 512
#     nr_layers: 6
#     skip_connections: false
#     activation_fn: silu
#     adaptive_activations: false
#     weight_norm: true
# models: ???
# loss:
#   _target_: modulus.sym.loss.aggregator.Sum
#   weights: null
# optimizer:
#   _params_:
#     compute_gradients: adam_compute_gradients
#     apply_gradients: adam_apply_gradients
#   _target_: torch.optim.Adam
#   lr: 0.001
#   betas:
#   - 0.9
#   - 0.999
#   eps: 1.0e-08
#   weight_decay: 0.0
#   amsgrad: false
# scheduler:
#   _target_: custom
#   _name_: tf.ExponentialLR
#   decay_rate: 0.95
#   decay_steps: 4000
# batch_size:
#   TopWall: 1000
#   NoSlip: 1000
#   Interior: 4000
# custom: ???

# %% [markdown]
# # Create Solver

# %%
from modulus.sym.solver import Solver

slv = Solver(cfg, ldc_domain)

# %% [markdown]
# # Run Solver

# %% [markdown]
# First configure the logging to see the steps!

# %%
import logging

# Create a function to configure logging
def configure_logging():
    # Get the root logger
    logger = logging.getLogger()
    logger.setLevel(logging.DEBUG)

    # Remove all existing handlers
    while logger.handlers:
        logger.handlers.pop()

    # Create a stream handler
    stream_handler = logging.StreamHandler()
    stream_handler.setLevel(logging.DEBUG)

    # Create a formatter
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    stream_handler.setFormatter(formatter)

    # Add the handler to the logger
    logger.addHandler(stream_handler)

# Configure logging
configure_logging()

# Test logging
logging.debug("Logging is configured correctly.")
# Out:
# 2024-08-14 13:45:58,715 - root - DEBUG - Logging is configured correctly.

# %%
slv.solve()
# Out:
# 2024-08-14 13:46:02,179 - modulus.sym.trainer - WARNING - Installed PyTorch version 2.3.1+cu121 is not TorchScript supported in Modulus. Version 2.1.0a0+4136153 is officially supported.
# 2024-08-14 13:46:02,193 - modulus.sym.trainer - INFO - attempting to restore from: /content/outputs
# 2024-08-14 13:46:02,195 - modulus.sym.trainer - WARNING - optimizer checkpoint not found
# 2024-08-14 13:46:02,197 - modulus.sym.trainer - WARNING - model flow_network.0.pth not found
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at ../aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# 2024-08-14 14:21:46,930 - modulus.sym.trainer - INFO - [step:       9600] loss:  1.476e-04, time/iteration:  2.205e+02 ms
# 2024-08-14 14:22:08,997 - modulus.sym.trainer - INFO - [step:       9700] loss:  1.156e-04, time/iteration:  2.206e+02 ms
# 2024-08-14 14:22:31,286 - modulus.sym.trainer - INFO - [step:       9800] loss:  2.399e-04, time/iteration:  2.229e+02 ms
# 2024-08-14 14:22:53,423 - modulus.sym.trainer - INFO - [step:       9900] loss:  2.168e-04, time/iteration:  2.214e+02 ms
# 2024-08-14 14:23:16,625 - modulus.sym.trainer - DEBUG - [step:      10000] saved constraint results to outputs
# 2024-08-14 14:23:16,627 - modulus.sym.trainer - INFO - [step:      10000] record constraint batch time:  1.481e-01s
# 2024-08-14 14:23:16,678 - modulus.sym.trainer - INFO - [step:      10000] saved checkpoint to /content/outputs
# 2024-08-14 14:23:16,681 - modulus.sym.trainer - INFO - [step:      10000] loss:  2.344e-04, time/iteration:  2.325e+02 ms
# 2024-08-14 14:23:16,683 - modulus.sym.trainer - INFO - [step:      10000] reached maximum training steps, finished training!

# %% [markdown]
# # Output Files

# %% [markdown]
# ## Load Model From File

# %%
torch.load('./outputs/optim_checkpoint.0.pth').keys()
# Out:
# dict_keys(['step', 'optimizer_state_dict', 'aggregator_state_dict', 'scheduler_state_dict', 'scaler_state_dict'])

# %%
torch.load('./outputs/flow_network.0.pth').keys()
# Out:
# odict_keys(['_impl.layers.0.linear.weight', '_impl.layers.0.linear.weight_g', '_impl.layers.0.linear.bias', '_impl.layers.1.linear.weight', '_impl.layers.1.linear.weight_g', '_impl.layers.1.linear.bias', '_impl.layers.2.linear.weight', '_impl.layers.2.linear.weight_g', '_impl.layers.2.linear.bias', '_impl.layers.3.linear.weight', '_impl.layers.3.linear.weight_g', '_impl.layers.3.linear.bias', '_impl.layers.4.linear.weight', '_impl.layers.4.linear.weight_g', '_impl.layers.4.linear.bias', '_impl.layers.5.linear.weight', '_impl.layers.5.linear.weight_g', '_impl.layers.5.linear.bias', '_impl.final_layer.linear.weight', '_impl.final_layer.linear.bias'])

# %%
# checkpoint = torch.load('./outputs/optim_checkpoint.0.pth')
checkpoint = torch.load('/content/outputs/flow_network.0.pth')
try:
    checkpoint.eval()
except AttributeError as error:
    print(error)

# https://stackoverflow.com/a/51812173/8062488 (simiar to this, but not exactly)
# flow_net.load_state_dict(checkpoint['state_dict'])

flow_net.load_state_dict(checkpoint)
# Out:
# 'collections.OrderedDict' object has no attribute 'eval'
# <All keys matched successfully>

# %% [markdown]
# ## How to evaluate a PyTorch model

# %%
flow_net
# Out:
# FullyConnectedArch(
#   (_impl): FullyConnectedArchCore(
#     (layers): ModuleList(
#       (0): FCLayer(
#         (linear): WeightNormLinear(in_features=2, out_features=512, bias=True)
#       )
#       (1-5): 5 x FCLayer(
#         (linear): WeightNormLinear(in_features=512, out_features=512, bias=True)
#       )
#     )
#     (final_layer): FCLayer(
#       (activation_fn): Identity()
#       (linear): Linear(in_features=512, out_features=3, bias=True)
#     )
#   )
# )

# %% [markdown]
# ```
# FullyConnectedArch: def _wrapped_call_impl(*args, **kwargs)
# Activation.SILU
# [N, size]
# [N, size]
# >>> arch = .fully_connected.FullyConnectedArch(
# >>>    [Key("x", size=2)],
# >>>    [Key("y", size=2)],
# >>>    layer_size = 64,
# >>>    nr_layers = 2)
# >>> model = arch.make_node()
# >>> input = {"x": torch.randn(64, 2)}
# >>> output = model.evaluate(input)
# >>> arch = .fully_connected.FullyConnectedArch(
# >>>    [Key("x", size=2)],
# >>>    [Key("y", size=2)],
# >>>    periodicity={'x': (0, 1)})
# ```

# %%
# Example
arch = FullyConnectedArch(
[Key("x", size=2)], # input layer has two values, or is an "x" of dimension 2
[Key("y", size=2)], # output layers also outputs the same kind of thig here
layer_size = 64,
nr_layers = 2)
model = arch.make_node(name="test_model")
input = {"x": torch.randn(10, 2)}
output = model.evaluate(input)
output
# Out:
# {'y': tensor([[ 0.3870, -0.2317],
#          [ 0.0737, -0.1425],
#          [ 0.2509, -0.1701],
#          [-0.1976, -0.3531],
#          [ 0.0207,  0.1792],
#          [-0.0352,  0.2394],
#          [ 0.1578, -0.4441],
#          [ 0.5932, -0.3739],
#          [ 0.0379,  0.0667],
#          [ 0.1624, -0.3684]], grad_fn=<SplitWithSizesBackward0>)}

# %%
arch(input)
# Out:
# {'y': tensor([[ 0.3870, -0.2317],
#          [ 0.0737, -0.1425],
#          [ 0.2509, -0.1701],
#          [-0.1976, -0.3531],
#          [ 0.0207,  0.1792],
#          [-0.0352,  0.2394],
#          [ 0.1578, -0.4441],
#          [ 0.5932, -0.3739],
#          [ 0.0379,  0.0667],
#          [ 0.1624, -0.3684]], grad_fn=<SplitWithSizesBackward0>)}

# %%
torch.randn(10, 2)
# Out:
# tensor([[ 0.7699, -0.7289],
#         [-1.1688, -1.1042],
#         [-0.0234,  0.0765],
#         [-0.8711, -0.1513],
#         [ 0.4424, -0.4740],
#         [ 1.3565,  0.7717],
#         [-0.4679, -1.5165],
#         [-0.0772,  0.5848],
#         [-1.2188,  0.2961],
#         [ 0.7626,  1.1412]])

# %% [markdown]
# # How to evaluate **OUR** PyTorch flow model

# %% [markdown]
# This is why we instantiated it like this.

# %% [markdown]
# ```
# flow_net = FullyConnectedArch(
#     input_keys=[Key("x"), Key("y")],
#     output_keys=[Key("u"), Key("v"), Key("p")],
#     layer_size=512,
#     nr_layers=6,
#     skip_connections=False,
#     activation_fn=Activation.SILU,
#     adaptive_activations=False,
#     weight_norm=True,
# )
# ```

# %%
torch.randn(5, 1)
# Out:
# tensor([[ 2.1417],
#         [ 0.2518],
#         [ 0.1404],
#         [-1.2679],
#         [-1.6961]])

# %%
torch.tensor([0.04])
# Out:
# tensor([0.0400])

# %%
torch.rand(5, 1)
# Out:
# tensor([[0.0482],
#         [0.5096],
#         [0.5343],
#         [0.6394],
#         [0.5257]])

# %%
import torch

# Define the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Ensure all tensors are on the same device
# A top wall point (x,y) = [0, 0.05]

inputs = {
    "x": torch.tensor([0], device=device),
    "y": torch.tensor([0.05], device=device)
}

# Call the model with tensors on the correct device
output = flow_net(inputs)

# %%
(torch.rand(5, 1) * 0.1) - 0.05
# Out:
# tensor([[ 0.0471],
#         [ 0.0417],
#         [ 0.0032],
#         [-0.0345],
#         [ 0.0387]])

# %%
flow_net({"x": (torch.rand(5, 1,device=device) * 0.1) -0.05, "y": (torch.rand(5, 1,device=device) * 0.1) -0.05} )
# Out:
# {'u': tensor([[-0.0185],
#          [-0.0207],
#          [ 0.1047],
#          [-0.0120],
#          [-0.0948]], device='cuda:0', grad_fn=<SplitWithSizesBackward0>),
#  'v': tensor([[ 0.0116],
#          [-0.0458],
#          [ 0.1654],
#          [ 0.0163],
#          [ 0.0837]], device='cuda:0', grad_fn=<SplitWithSizesBackward0>),
#  'p': tensor([[-0.1452],
#          [-0.0830],
#          [-0.5614],
#          [-0.1400],
#          [-0.1677]], device='cuda:0', grad_fn=<SplitWithSizesBackward0>)}

# %%
flow_net({"x": torch.tensor([0.05],device=device), "y": torch.tensor([0],device=device)} )
# Out:
# {'u': tensor([-0.0007], device='cuda:0', grad_fn=<SplitWithSizesBackward0>),
#  'v': tensor([-0.0101], device='cuda:0', grad_fn=<SplitWithSizesBackward0>),
#  'p': tensor([-0.0654], device='cuda:0', grad_fn=<SplitWithSizesBackward0>)}

# %% [markdown]
# # Finally, how to visualize our results

# %%
# Define the domain
x_values = np.linspace(-0.05, 0.05, 100)
y_values = np.linspace(-0.05, 0.05, 100)
x_grid, y_grid = np.meshgrid(x_values, y_values)

# Flatten the grid arrays to create inputs for the model
x_flat = x_grid.flatten()
y_flat = y_grid.flatten()

# Convert to PyTorch tensors
x_tensor = torch.tensor(x_flat, dtype=torch.float32,device=device).unsqueeze(1)
y_tensor = torch.tensor(y_flat, dtype=torch.float32,device=device).unsqueeze(1)

# Create input dictionary for the model
inputs = {"x": x_tensor, "y": y_tensor}

# %%
# Pass inputs through the model to get predictions
outputs = flow_net(inputs)
u_flat = outputs['u'].detach().cpu().numpy()
v_flat = outputs['v'].detach().cpu().numpy()
p_flat = outputs['p'].detach().cpu().numpy()

# Reshape the outputs back to grid shape
u_grid = u_flat.reshape(x_grid.shape)
v_grid = v_flat.reshape(x_grid.shape)
p_grid = p_flat.reshape(x_grid.shape)

# %%
import matplotlib.pyplot as plt

# Plot the color maps with 'jet' colormap
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot p
im0 = axs[0].imshow(p_grid, extent=[-0.05, 0.05, -0.05, 0.05], origin='lower', aspect='auto', cmap='jet')
axs[0].set_title('p')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
fig.colorbar(im0, ax=axs[0])

# Plot u
im1 = axs[1].imshow(u_grid, extent=[-0.05, 0.05, -0.05, 0.05], origin='lower', aspect='auto', cmap='jet')
axs[1].set_title('u')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')
fig.colorbar(im1, ax=axs[1])

# Plot v
im2 = axs[2].imshow(v_grid, extent=[-0.05, 0.05, -0.05, 0.05], origin='lower', aspect='auto', cmap='jet')
axs[2].set_title('v')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')
fig.colorbar(im2, ax=axs[2])

plt.tight_layout()
plt.show()
# Out:
# 2024-08-14 14:45:45,912 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fa9018541c0>
# 2024-08-14 14:45:45,939 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fa901885c00>
# 2024-08-14 14:45:45,961 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fa9018b72b0>

# %%
# Define the domain
x_values = np.linspace(-0.05, 0.05, 20)  # Reduced number of points for clearer vector field
y_values = np.linspace(-0.05, 0.05, 20)
x_grid, y_grid = np.meshgrid(x_values, y_values)

# Flatten the grid arrays to create inputs for the model
x_flat = x_grid.flatten()
y_flat = y_grid.flatten()

# Convert to PyTorch tensors
x_tensor = torch.tensor(x_flat, dtype=torch.float32,device=device).unsqueeze(1)
y_tensor = torch.tensor(y_flat, dtype=torch.float32,device=device).unsqueeze(1)

# Create input dictionary for the model
inputs = {"x": x_tensor, "y": y_tensor}

# Pass inputs through the model to get predictions
outputs = flow_net(inputs)
u_flat = outputs['u'].detach().cpu().numpy()
v_flat = outputs['v'].detach().cpu().numpy()

# Reshape the outputs back to grid shape
u_grid = u_flat.reshape(x_grid.shape)
v_grid = v_flat.reshape(x_grid.shape)

# Plot the vector field
plt.figure(figsize=(8, 6))
plt.quiver(x_grid, y_grid, u_grid, v_grid, scale=10, color='blue')  # Adjust scale as needed
plt.title('Vector Field of u and v')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-0.05, 0.05])
plt.ylim([-0.05, 0.05])
plt.grid(True)
plt.show()

# %%
# Calculate the magnitude of the vectors
magnitude = np.sqrt(u_grid**2 + v_grid**2)

# Plot the vector field with colors
plt.figure(figsize=(8, 6))
plt.quiver(x_grid, y_grid, u_grid, v_grid, magnitude, scale=10, cmap='jet')  # Adjust scale as needed
plt.colorbar(label='Magnitude')
plt.title('Vector Field of u and v')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-0.05, 0.05])
plt.ylim([-0.05, 0.05])
plt.grid(True)
plt.show()
# Out:
# 2024-08-14 14:48:08,828 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fa900c4ff70>

# %%
# Plot streamlines
plt.figure(figsize=(8, 6))
plt.streamplot(x_grid, y_grid, u_grid, v_grid, color=magnitude, cmap='jet')
plt.colorbar(label='Magnitude')
plt.title('Streamlines of u and v')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-0.05, 0.05])
plt.ylim([-0.05, 0.05])
plt.grid(True)
plt.show()
# Out:
# 2024-08-14 14:48:25,088 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x7fa900ab9900>
